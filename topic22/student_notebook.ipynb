# %% [markdown]
# # Objectives
# YWBAT
# * identify a dot product
# * write other equations in terms of a dot product
# * solve linear regression using dot products and matrix multiplication

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/OLSChallenge.csv", encoding="ISO-8859-1")
df.head()
# Out:
#    avgAnnCount  avgDeathsPerYear  TARGET_deathRate  incidenceRate  medIncome  \
# 0       1397.0               469             164.9          489.8      61898
# 1        173.0                70             161.3          411.6      48127
# 2        102.0                50             174.7          349.7      49348
# 3        427.0               202             194.8          430.4      44243
# 4         57.0                26             144.4          350.1      49955
#
#    popEst2015  povertyPercent  studyPerCap           binnedInc  MedianAge  \
# 0      260131            11.2   499.748204   (61494.5, 125635]       39.3
# 1       43269            18.6    23.111234  (48021.6, 51046.4]       33.0
# 2       21026            14.6    47.560164  (48021.6, 51046.4]       45.0
# 3       75882            17.1   342.637253    (42724.4, 45201]       42.8
# 4       10321            12.5     0.000000  (48021.6, 51046.4]       48.3
#
# ...

# %%
# Let's take a subset of this data
# target = 'TARGET_deathRate'
# subset = ['incidenceRate', 'avgDeathsPerYear', 'popEst2015', 'povertyPercent']

target = "TARGET_deathRate"
subset = ['incidenceRate', 'avgDeathsPerYear', 'popEst2015', 'povertyPercent']

# %%
y = df[target]
X = df[subset]

# %%
X.head()
# Out:
#    incidenceRate  avgDeathsPerYear  popEst2015  povertyPercent
# 0          489.8               469      260131            11.2
# 1          411.6                70       43269            18.6
# 2          349.7                50       21026            14.6
# 3          430.4               202       75882            17.1
# 4          350.1                26       10321            12.5

# %% [markdown]
# # let's calculate some dot products

# %%
# lists vs arrays

# %%
# Let's do some linear regression by hand!

# %%
y.shape, X.shape
# Out:
# ((3047,), (3047, 4))
